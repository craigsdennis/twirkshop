# %%
import os
import pandas as pd

bikes = pd.read_csv('201811-fordgobike-tripdata.csv')

# %%
bikes.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         79489  2018-11-30 13:40:32.7690  2018-12-01 11:45:21.9720
# 1         42847  2018-11-30 20:13:45.5090  2018-12-01 08:07:53.1330
# 2          1128  2018-11-30 23:58:26.4310  2018-12-01 00:17:14.4880
# 3          2476  2018-11-30 23:35:06.7230  2018-12-01 00:16:23.4740
# 4          1273  2018-11-30 23:54:12.3890  2018-12-01 00:15:26.3680
#
#    start_station_id                                 start_station_name  \
# 0               NaN                                                NaN
# 1              37.0                                2nd St at Folsom St
# 2             249.0                          Russell St at College Ave
# 3             104.0                                  4th St at 16th St
# 4              44.0  Civic Center/UN Plaza BART Station (Market St ...
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
bikes.start_station_name.value_counts().head(10).plot.bar();

# %%
bikes.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  134135.000000     133651.000000           134135.000000
# mean      757.954031        128.578088               37.765055
# std      1858.909321        107.997019                0.109212
# min        61.000000          3.000000               37.317298
# 25%       341.000000         37.000000               37.770407
# 50%       537.000000         92.000000               37.780955
# 75%       824.000000        206.000000               37.795392
# max     85983.000000        381.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            134135.000000   133651.000000         134135.000000
# mean               -122.348287      127.012809             37.765172
# std                   0.126561      107.934082              0.109037
# min                -122.453704        3.000000             37.317298
# ...

# %%
bikes.member_gender.value_counts().plot.pie();
